# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Data generation

# %%
# Number of points per cluster
N = 10000

# Generate random cluster points
c1 = np.random.normal(loc=[0, 1], scale=[0.5, 0.75], size=(N, 2))
c2 = np.random.normal(loc=[2, 2.2], scale=[0.5, 0.75], size=(N, 2))
c3 = np.random.normal(loc=[5, 7], scale=[0.25, 0.8], size=(N, 2))

data = np.concatenate((c1, c2, c3), axis=0)
data
# Out:
# array([[-0.64328306,  0.60690625],
#        [-0.14068843,  0.7649572 ],
#        [-0.17697855,  1.58267546],
#        ...,
#        [ 5.12873692,  6.4339728 ],
#        [ 4.9368305 ,  6.53874814],
#        [ 4.96317408,  6.57000434]])

# %%
#######################################
# Plots
#######################################
fig, ax = plt.subplots(figsize=(20, 10))

ax.scatter(data[:,0], data[:,1])

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')

ax.set_title('Generated Data (N=10k)', size=20)

plt.savefig('figs/generated_data_N_10k.png', dpi=300)
plt.show()

# %% [markdown]
# ---
# # Fitted data

# %% [markdown]
# (Taking *initial_centroids* and *means* from one run of the algorithm with $k=3, n_nodes=8, max_n_iter=10$)

# %%
fig, ax = plt.subplots(figsize=(20, 10))

ax1 = plt.scatter(l[:,0], l[:,1])
ax2 = plt.scatter(m[:,0], m[:,1])
ax3 = plt.scatter(n[:,0], n[:,1])

ax4 = plt.scatter(np.array(list(initial_centroids.values()))[:,0], np.array(list(initial_centroids.values()))[:,1], 
                  s=100, 
                  marker="D", 
                  color="#00eeff"
                 )
ax5 = plt.scatter(np.array(list(means.values()))[:,0], np.array(list(means.values()))[:,1], 
                  s=100, 
                  marker="X", 
                  color="#1eff00"
                 )


# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')


plt.legend((ax4, ax5),
           ('Initial centroids', 'Fitted centroids'),
           scatterpoints=1,
           loc='upper left',
           ncol=3,
           fontsize=10)

plt.title('Fitted Data', size=20)

plt.savefig('figs/fitted_data_N_10k.png', dpi=300)
plt.show()
